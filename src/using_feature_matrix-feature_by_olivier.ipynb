# %%
import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier

import time
import gc
from tqdm import tqdm

# %%
st = time.time()
df = pd.read_csv('./new_feature_by_olivier_feature_matrix.csv')
time.time() - st
# Out:
# 187.1064031124115

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_feats = [f for f in df.columns if df[f].dtype == 'object']
for col in tqdm(categorical_feats):
    if col == 'set' :
        continue
    df[col] = df[col].astype('str')
    le.fit(df[col])
    df[col] = le.transform(df[col])
train_df = df.loc[df['set'] == 'train'] .drop('set', axis = 1)
test_df = df.loc[df['set'] == 'test'] .drop(['set', 'TARGET'], axis=1)

del df
gc.collect()
# Out:
# 100%|██████████| 39/39 [00:45<00:00,  1.16s/it]
# 36

# %%
oof_preds = np.zeros(train_df.shape[0])
sub_preds = np.zeros(test_df.shape[0])

feature_importance_df = pd.DataFrame()
y = train_df['TARGET'].copy()
X = train_df.drop('TARGET', axis = 1)


feats =  list(X.columns)

folds = KFold(n_splits=5, shuffle=True, random_state=2018)
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(X)):
    train_X, train_y = X.iloc[trn_idx], y.iloc[trn_idx]
    valid_X, valid_y = X.iloc[val_idx], y.iloc[val_idx]

    clf = LGBMClassifier(
        n_estimators=4000,
        learning_rate=0.03,
        num_leaves=30,
        colsample_bytree=.8,
        subsample=.9,
        max_depth=7,
        reg_alpha=.1,
        reg_lambda=.1,
        min_split_gain=.01,
        min_child_weight=2,
        silent=-1,
        verbose=-1,
    )

    clf.fit(train_X, train_y, 
            eval_set= [(train_X, train_y), (valid_X, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100  #30
           )

    oof_preds[val_idx] = clf.predict_proba(valid_X, num_iteration=clf.best_iteration_)[:, 1]
    sub_preds += clf.predict_proba(test_df, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[val_idx])))
    del clf, train_X, train_y, valid_X, valid_y
    gc.collect()

print('Full AUC score %.6f' % roc_auc_score(y, oof_preds)) 

sub = pd.read_csv('../input/sample_submission.csv')
sub['TARGET'] = sub_preds
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.77106	valid_1's auc: 0.755885
# [200]	training's auc: 0.801589	valid_1's auc: 0.772253
# [300]	training's auc: 0.821009	valid_1's auc: 0.779543
# [400]	training's auc: 0.835955	valid_1's auc: 0.782165
# [500]	training's auc: 0.849321	valid_1's auc: 0.7838
# [600]	training's auc: 0.861118	valid_1's auc: 0.784438
# [700]	training's auc: 0.871617	valid_1's auc: 0.784962
# [800]	training's auc: 0.880871	valid_1's auc: 0.785471
# [900]	training's auc: 0.889565	valid_1's auc: 0.785352
# Early stopping, best iteration is:
# [806]	training's auc: 0.881421	valid_1's auc: 0.785502
# Fold  1 AUC : 0.785502
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.771189	valid_1's auc: 0.756249
# [200]	training's auc: 0.801982	valid_1's auc: 0.773292
# [300]	training's auc: 0.821164	valid_1's auc: 0.780136
# [400]	training's auc: 0.83632	valid_1's auc: 0.78345
# [500]	training's auc: 0.849403	valid_1's auc: 0.785128
# [600]	training's auc: 0.860554	valid_1's auc: 0.786044
# [700]	training's auc: 0.870854	valid_1's auc: 0.786613
# [800]	training's auc: 0.880362	valid_1's auc: 0.787121
# [900]	training's auc: 0.889218	valid_1's auc: 0.787706
# [1000]	training's auc: 0.896978	valid_1's auc: 0.787733
# Early stopping, best iteration is:
# [934]	training's auc: 0.892038	valid_1's auc: 0.787773
# Fold  2 AUC : 0.787773
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.770904	valid_1's auc: 0.752641
# [200]	training's auc: 0.800688	valid_1's auc: 0.77334
# [300]	training's auc: 0.820464	valid_1's auc: 0.782297
# [400]	training's auc: 0.835738	valid_1's auc: 0.786515
# [500]	training's auc: 0.849172	valid_1's auc: 0.788558
# [600]	training's auc: 0.860711	valid_1's auc: 0.78972
# [700]	training's auc: 0.871394	valid_1's auc: 0.790573
# [800]	training's auc: 0.880579	valid_1's auc: 0.791093
# [900]	training's auc: 0.889335	valid_1's auc: 0.791376
# Early stopping, best iteration is:
# [876]	training's auc: 0.887257	valid_1's auc: 0.791447
# Fold  3 AUC : 0.791447
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.769171	valid_1's auc: 0.76006
# [200]	training's auc: 0.799862	valid_1's auc: 0.778896
# [300]	training's auc: 0.819775	valid_1's auc: 0.786412
# [400]	training's auc: 0.835511	valid_1's auc: 0.7899
# [500]	training's auc: 0.848808	valid_1's auc: 0.791406
# [600]	training's auc: 0.860816	valid_1's auc: 0.792469
# [700]	training's auc: 0.871259	valid_1's auc: 0.792337
# Early stopping, best iteration is:
# [602]	training's auc: 0.861007	valid_1's auc: 0.792493
# Fold  4 AUC : 0.792493
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.770477	valid_1's auc: 0.757953
# [200]	training's auc: 0.801164	valid_1's auc: 0.776201
# [300]	training's auc: 0.820827	valid_1's auc: 0.782836
# [400]	training's auc: 0.836041	valid_1's auc: 0.785598
# [500]	training's auc: 0.849665	valid_1's auc: 0.787193
# [600]	training's auc: 0.86142	valid_1's auc: 0.787939
# [700]	training's auc: 0.871861	valid_1's auc: 0.788395
# [800]	training's auc: 0.881501	valid_1's auc: 0.78838
# Early stopping, best iteration is:
# [705]	training's auc: 0.872396	valid_1's auc: 0.788442
# Fold  5 AUC : 0.788442
# Full AUC score 0.789060

# %%
sub.to_csv('./olivier_feature_matrix_5cv_sub.csv', index=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

def display_importances(feature_importance_df_):
    # Plot feature importances
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:50].index
    
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    
    plt.figure(figsize=(8,10))
    sns.barplot(x="importance", y="feature", 
                data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()

# %%
display_importances(feature_importance_df)

# %%
time.time() - st
# Out:
# 2131.275969982147

# %% [markdown]
# # parameter tuned
# reference : https://www.kaggle.com/znyksh/fork-lightgbm-with-simple-features/versions#base=4143658&new=4153250

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier

import time
import gc
from tqdm import tqdm

# %%
st = time.time()
df = pd.read_csv('./new_feature_by_kageyama_feature_matrix_noIDs.csv')
time.time() - st
# Out:
# 120.1052942276001

# %%
df = df.drop('SK_ID_CURR', axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_feats = [f for f in df.columns if df[f].dtype == 'object']
for col in tqdm(categorical_feats):
    if col == 'set' :
        continue
    df[col] = df[col].astype('str')
    le.fit(df[col])
    df[col] = le.transform(df[col])
train_df = df.loc[df['set'] == 'train'] .drop('set', axis = 1)
test_df = df.loc[df['set'] == 'test'] .drop(['set', 'TARGET'], axis=1)

del df
gc.collect()
# Out:
# 100%|██████████| 39/39 [00:43<00:00,  1.11s/it]
# 36

# %%
oof_preds = np.zeros(train_df.shape[0])
sub_preds = np.zeros(test_df.shape[0])

feature_importance_df = pd.DataFrame()
y = train_df['TARGET'].copy()
X = train_df.drop('TARGET', axis = 1)


feats =  list(X.columns)

folds = KFold(n_splits=25, shuffle=True, random_state=2018)
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(X)):
    train_X, train_y = X.iloc[trn_idx], y.iloc[trn_idx]
    valid_X, valid_y = X.iloc[val_idx], y.iloc[val_idx]

    clf = LGBMClassifier(
        n_estimators=4000,
        learning_rate=0.02,
        num_leaves=32,
        colsample_bytree=.8,
        subsample=.87,
        max_depth=8,
        reg_alpha=.0415,
        reg_lambda=.0735,
        min_split_gain=.02,
        min_child_weight=40,
        silent=-1,
        verbose=-1,
    )

    clf.fit(train_X, train_y, 
            eval_set= [(train_X, train_y), (valid_X, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100  #30
           )

    oof_preds[val_idx] = clf.predict_proba(valid_X, num_iteration=clf.best_iteration_)[:, 1]
    sub_preds += clf.predict_proba(test_df, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[val_idx])))
    del clf, train_X, train_y, valid_X, valid_y
    gc.collect()

print('Full AUC score %.6f' % roc_auc_score(y, oof_preds)) 

sub = pd.read_csv('../input/sample_submission.csv')
sub['TARGET'] = sub_preds
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758766	valid_1's auc: 0.751971
# [200]	training's auc: 0.780869	valid_1's auc: 0.764686
# [300]	training's auc: 0.79807	valid_1's auc: 0.774438
# [400]	training's auc: 0.809729	valid_1's auc: 0.779476
# [500]	training's auc: 0.818902	valid_1's auc: 0.782489
# [600]	training's auc: 0.826994	valid_1's auc: 0.783755
# [700]	training's auc: 0.833981	valid_1's auc: 0.784831
# [800]	training's auc: 0.840603	valid_1's auc: 0.78592
# [900]	training's auc: 0.84636	valid_1's auc: 0.786711
# [1000]	training's auc: 0.851918	valid_1's auc: 0.78725
# [1100]	training's auc: 0.857067	valid_1's auc: 0.787744
# [1200]	training's auc: 0.861734	valid_1's auc: 0.787783
# [1300]	training's auc: 0.86643	valid_1's auc: 0.788034
# [1400]	training's auc: 0.871036	valid_1's auc: 0.788381
# [1500]	training's auc: 0.875265	valid_1's auc: 0.788493
# [1600]	training's auc: 0.879333	valid_1's auc: 0.788859
# [1700]	training's auc: 0.883103	valid_1's auc: 0.789087
# [1800]	training's auc: 0.887128	valid_1's auc: 0.789295
# [1900]	training's auc: 0.891012	valid_1's auc: 0.789525
# [2000]	training's auc: 0.894761	valid_1's auc: 0.789599
# [2100]	training's auc: 0.898123	valid_1's auc: 0.789552
# Early stopping, best iteration is:
# [2032]	training's auc: 0.895831	valid_1's auc: 0.789732
# Fold  1 AUC : 0.789732
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759099	valid_1's auc: 0.748183
# [200]	training's auc: 0.78064	valid_1's auc: 0.763376
# [300]	training's auc: 0.798023	valid_1's auc: 0.774701
# [400]	training's auc: 0.809687	valid_1's auc: 0.780967
# [500]	training's auc: 0.818881	valid_1's auc: 0.784847
# [600]	training's auc: 0.826697	valid_1's auc: 0.787438
# [700]	training's auc: 0.833842	valid_1's auc: 0.78905
# [800]	training's auc: 0.840198	valid_1's auc: 0.790385
# [900]	training's auc: 0.845898	valid_1's auc: 0.791384
# [1000]	training's auc: 0.851291	valid_1's auc: 0.792345
# [1100]	training's auc: 0.856544	valid_1's auc: 0.793042
# [1200]	training's auc: 0.861354	valid_1's auc: 0.793476
# [1300]	training's auc: 0.865967	valid_1's auc: 0.793709
# [1400]	training's auc: 0.870572	valid_1's auc: 0.79406
# [1500]	training's auc: 0.874908	valid_1's auc: 0.794422
# [1600]	training's auc: 0.879025	valid_1's auc: 0.795158
# [1700]	training's auc: 0.882982	valid_1's auc: 0.79557
# [1800]	training's auc: 0.886823	valid_1's auc: 0.795398
# Early stopping, best iteration is:
# [1726]	training's auc: 0.883989	valid_1's auc: 0.795626
# Fold  2 AUC : 0.795626
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759332	valid_1's auc: 0.748399
# [200]	training's auc: 0.780851	valid_1's auc: 0.763771
# [300]	training's auc: 0.798204	valid_1's auc: 0.773248
# [400]	training's auc: 0.809821	valid_1's auc: 0.777653
# [500]	training's auc: 0.818934	valid_1's auc: 0.779851
# [600]	training's auc: 0.827044	valid_1's auc: 0.781067
# [700]	training's auc: 0.833937	valid_1's auc: 0.782057
# [800]	training's auc: 0.840365	valid_1's auc: 0.782277
# [900]	training's auc: 0.846405	valid_1's auc: 0.783002
# [1000]	training's auc: 0.852117	valid_1's auc: 0.78328
# [1100]	training's auc: 0.857185	valid_1's auc: 0.783576
# [1200]	training's auc: 0.861902	valid_1's auc: 0.783899
# [1300]	training's auc: 0.866668	valid_1's auc: 0.784441
# [1400]	training's auc: 0.871085	valid_1's auc: 0.7845
# [1500]	training's auc: 0.875454	valid_1's auc: 0.784577
# [1600]	training's auc: 0.879481	valid_1's auc: 0.784456
# Early stopping, best iteration is:
# [1539]	training's auc: 0.877104	valid_1's auc: 0.784737
# Fold  3 AUC : 0.784737
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759376	valid_1's auc: 0.743018
# [200]	training's auc: 0.781212	valid_1's auc: 0.75795
# [300]	training's auc: 0.798245	valid_1's auc: 0.768094
# [400]	training's auc: 0.809798	valid_1's auc: 0.773209
# [500]	training's auc: 0.818826	valid_1's auc: 0.776927
# [600]	training's auc: 0.826942	valid_1's auc: 0.77897
# [700]	training's auc: 0.834146	valid_1's auc: 0.780598
# [800]	training's auc: 0.840655	valid_1's auc: 0.781731
# [900]	training's auc: 0.846318	valid_1's auc: 0.783026
# [1000]	training's auc: 0.851667	valid_1's auc: 0.783144
# [1100]	training's auc: 0.856778	valid_1's auc: 0.783782
# [1200]	training's auc: 0.861725	valid_1's auc: 0.784149
# [1300]	training's auc: 0.866308	valid_1's auc: 0.784575
# [1400]	training's auc: 0.870836	valid_1's auc: 0.784587
# Early stopping, best iteration is:
# [1307]	training's auc: 0.866655	valid_1's auc: 0.784649
# Fold  4 AUC : 0.784649
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758949	valid_1's auc: 0.7512
# [200]	training's auc: 0.780844	valid_1's auc: 0.768664
# [300]	training's auc: 0.797876	valid_1's auc: 0.779023
# [400]	training's auc: 0.809476	valid_1's auc: 0.784065
# [500]	training's auc: 0.818765	valid_1's auc: 0.787549
# [600]	training's auc: 0.826724	valid_1's auc: 0.78989
# [700]	training's auc: 0.833986	valid_1's auc: 0.791595
# [800]	training's auc: 0.840425	valid_1's auc: 0.792639
# [900]	training's auc: 0.846375	valid_1's auc: 0.793432
# [1000]	training's auc: 0.851721	valid_1's auc: 0.794176
# [1100]	training's auc: 0.856782	valid_1's auc: 0.794793
# [1200]	training's auc: 0.861615	valid_1's auc: 0.794917
# [1300]	training's auc: 0.866235	valid_1's auc: 0.795516
# [1400]	training's auc: 0.870812	valid_1's auc: 0.795796
# [1500]	training's auc: 0.875163	valid_1's auc: 0.795861
# Early stopping, best iteration is:
# [1450]	training's auc: 0.872895	valid_1's auc: 0.796054
# Fold  5 AUC : 0.796054
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758963	valid_1's auc: 0.754614
# [200]	training's auc: 0.78069	valid_1's auc: 0.769873
# [300]	training's auc: 0.798161	valid_1's auc: 0.781589
# [400]	training's auc: 0.809608	valid_1's auc: 0.787928
# [500]	training's auc: 0.818786	valid_1's auc: 0.791371
# [600]	training's auc: 0.826619	valid_1's auc: 0.793383
# [700]	training's auc: 0.833953	valid_1's auc: 0.794992
# [800]	training's auc: 0.840359	valid_1's auc: 0.795893
# [900]	training's auc: 0.846215	valid_1's auc: 0.796609
# [1000]	training's auc: 0.851681	valid_1's auc: 0.797058
# [1100]	training's auc: 0.856986	valid_1's auc: 0.797626
# [1200]	training's auc: 0.861897	valid_1's auc: 0.797821
# [1300]	training's auc: 0.866649	valid_1's auc: 0.798204
# [1400]	training's auc: 0.871086	valid_1's auc: 0.798327
# [1500]	training's auc: 0.875376	valid_1's auc: 0.798474
# [1600]	training's auc: 0.879446	valid_1's auc: 0.798566
# Early stopping, best iteration is:
# [1596]	training's auc: 0.87924	valid_1's auc: 0.798645
# Fold  6 AUC : 0.798645
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759416	valid_1's auc: 0.742563
# [200]	training's auc: 0.780863	valid_1's auc: 0.758477
# [300]	training's auc: 0.79801	valid_1's auc: 0.77018
# [400]	training's auc: 0.80968	valid_1's auc: 0.775588
# [500]	training's auc: 0.818809	valid_1's auc: 0.77891
# [600]	training's auc: 0.826807	valid_1's auc: 0.781279
# [700]	training's auc: 0.834038	valid_1's auc: 0.783116
# [800]	training's auc: 0.840485	valid_1's auc: 0.784321
# [900]	training's auc: 0.846317	valid_1's auc: 0.785592
# [1000]	training's auc: 0.851804	valid_1's auc: 0.786736
# [1100]	training's auc: 0.856991	valid_1's auc: 0.787453
# [1200]	training's auc: 0.861707	valid_1's auc: 0.78806
# [1300]	training's auc: 0.866413	valid_1's auc: 0.78871
# [1400]	training's auc: 0.870807	valid_1's auc: 0.789034
# [1500]	training's auc: 0.875033	valid_1's auc: 0.789381
# [1600]	training's auc: 0.879188	valid_1's auc: 0.789614
# [1700]	training's auc: 0.883174	valid_1's auc: 0.789955
# [1800]	training's auc: 0.88701	valid_1's auc: 0.790057
# [1900]	training's auc: 0.890977	valid_1's auc: 0.789881
# Early stopping, best iteration is:
# [1815]	training's auc: 0.887625	valid_1's auc: 0.790077
# Fold  7 AUC : 0.790077
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759492	valid_1's auc: 0.745303
# [200]	training's auc: 0.780989	valid_1's auc: 0.760814
# [300]	training's auc: 0.798387	valid_1's auc: 0.77157
# [400]	training's auc: 0.809869	valid_1's auc: 0.777423
# [500]	training's auc: 0.819056	valid_1's auc: 0.780423
# [600]	training's auc: 0.827164	valid_1's auc: 0.782491
# [700]	training's auc: 0.834215	valid_1's auc: 0.783928
# [800]	training's auc: 0.840561	valid_1's auc: 0.784869
# [900]	training's auc: 0.846408	valid_1's auc: 0.785639
# [1000]	training's auc: 0.851969	valid_1's auc: 0.785924
# [1100]	training's auc: 0.857163	valid_1's auc: 0.786667
# [1200]	training's auc: 0.86194	valid_1's auc: 0.786938
# [1300]	training's auc: 0.866555	valid_1's auc: 0.787274
# [1400]	training's auc: 0.871035	valid_1's auc: 0.787339
# [1500]	training's auc: 0.875351	valid_1's auc: 0.787708
# [1600]	training's auc: 0.879383	valid_1's auc: 0.787709
# Early stopping, best iteration is:
# [1544]	training's auc: 0.877126	valid_1's auc: 0.788
# Fold  8 AUC : 0.788000
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759479	valid_1's auc: 0.746687
# [200]	training's auc: 0.781055	valid_1's auc: 0.75897
# [300]	training's auc: 0.798421	valid_1's auc: 0.768859
# [400]	training's auc: 0.81005	valid_1's auc: 0.774247
# [500]	training's auc: 0.81932	valid_1's auc: 0.777356
# [600]	training's auc: 0.827327	valid_1's auc: 0.779449
# [700]	training's auc: 0.834071	valid_1's auc: 0.780713
# [800]	training's auc: 0.840376	valid_1's auc: 0.781638
# [900]	training's auc: 0.846396	valid_1's auc: 0.782216
# [1000]	training's auc: 0.85174	valid_1's auc: 0.782723
# [1100]	training's auc: 0.856999	valid_1's auc: 0.783213
# [1200]	training's auc: 0.861593	valid_1's auc: 0.783883
# [1300]	training's auc: 0.866364	valid_1's auc: 0.783905
# [1400]	training's auc: 0.871081	valid_1's auc: 0.784445
# [1500]	training's auc: 0.875503	valid_1's auc: 0.784655
# [1600]	training's auc: 0.879776	valid_1's auc: 0.784982
# [1700]	training's auc: 0.883688	valid_1's auc: 0.785448
# [1800]	training's auc: 0.887442	valid_1's auc: 0.785629
# [1900]	training's auc: 0.891255	valid_1's auc: 0.78606
# [2000]	training's auc: 0.894751	valid_1's auc: 0.786177
# Early stopping, best iteration is:
# [1956]	training's auc: 0.893231	valid_1's auc: 0.786204
# Fold  9 AUC : 0.786204
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758907	valid_1's auc: 0.760244
# [200]	training's auc: 0.78079	valid_1's auc: 0.774595
# [300]	training's auc: 0.797886	valid_1's auc: 0.784321
# [400]	training's auc: 0.809434	valid_1's auc: 0.789969
# [500]	training's auc: 0.818491	valid_1's auc: 0.793333
# [600]	training's auc: 0.826505	valid_1's auc: 0.795793
# [700]	training's auc: 0.833681	valid_1's auc: 0.797085
# [800]	training's auc: 0.840036	valid_1's auc: 0.798245
# [900]	training's auc: 0.845911	valid_1's auc: 0.799002
# [1000]	training's auc: 0.851402	valid_1's auc: 0.799043
# [1100]	training's auc: 0.856553	valid_1's auc: 0.799307
# [1200]	training's auc: 0.861407	valid_1's auc: 0.799726
# [1300]	training's auc: 0.866022	valid_1's auc: 0.800246
# [1400]	training's auc: 0.870568	valid_1's auc: 0.800668
# [1500]	training's auc: 0.874881	valid_1's auc: 0.800694
# Early stopping, best iteration is:
# [1435]	training's auc: 0.872157	valid_1's auc: 0.800806
# Fold 10 AUC : 0.800806
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759166	valid_1's auc: 0.751871
# [200]	training's auc: 0.780435	valid_1's auc: 0.770124
# [300]	training's auc: 0.797716	valid_1's auc: 0.781799
# [400]	training's auc: 0.809461	valid_1's auc: 0.787516
# [500]	training's auc: 0.818721	valid_1's auc: 0.791203
# [600]	training's auc: 0.82671	valid_1's auc: 0.79344
# [700]	training's auc: 0.83401	valid_1's auc: 0.794939
# [800]	training's auc: 0.840364	valid_1's auc: 0.795879
# [900]	training's auc: 0.846291	valid_1's auc: 0.796513
# [1000]	training's auc: 0.851614	valid_1's auc: 0.796876
# [1100]	training's auc: 0.856812	valid_1's auc: 0.796964
# [1200]	training's auc: 0.861494	valid_1's auc: 0.79736
# [1300]	training's auc: 0.866221	valid_1's auc: 0.79769
# Early stopping, best iteration is:
# [1286]	training's auc: 0.865576	valid_1's auc: 0.797781
# Fold 11 AUC : 0.797781
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758607	valid_1's auc: 0.751069
# [200]	training's auc: 0.780337	valid_1's auc: 0.771776
# [300]	training's auc: 0.797438	valid_1's auc: 0.786283
# [400]	training's auc: 0.80928	valid_1's auc: 0.79281
# [500]	training's auc: 0.818661	valid_1's auc: 0.796864
# [600]	training's auc: 0.826535	valid_1's auc: 0.798873
# [700]	training's auc: 0.833907	valid_1's auc: 0.800829
# [800]	training's auc: 0.840358	valid_1's auc: 0.801973
# [900]	training's auc: 0.846271	valid_1's auc: 0.802823
# [1000]	training's auc: 0.851835	valid_1's auc: 0.803506
# [1100]	training's auc: 0.857098	valid_1's auc: 0.803919
# [1200]	training's auc: 0.861974	valid_1's auc: 0.804322
# [1300]	training's auc: 0.866819	valid_1's auc: 0.804493
# Early stopping, best iteration is:
# [1244]	training's auc: 0.86425	valid_1's auc: 0.804662
# Fold 12 AUC : 0.804662
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759462	valid_1's auc: 0.739117
# [200]	training's auc: 0.780996	valid_1's auc: 0.755162
# [300]	training's auc: 0.798154	valid_1's auc: 0.766668
# [400]	training's auc: 0.809916	valid_1's auc: 0.773059
# [500]	training's auc: 0.819097	valid_1's auc: 0.776496
# [600]	training's auc: 0.827018	valid_1's auc: 0.778613
# [700]	training's auc: 0.834196	valid_1's auc: 0.78055
# [800]	training's auc: 0.840617	valid_1's auc: 0.781805
# [900]	training's auc: 0.84643	valid_1's auc: 0.782793
# [1000]	training's auc: 0.851824	valid_1's auc: 0.783615
# [1100]	training's auc: 0.856972	valid_1's auc: 0.784073
# [1200]	training's auc: 0.862156	valid_1's auc: 0.784648
# [1300]	training's auc: 0.866652	valid_1's auc: 0.785333
# [1400]	training's auc: 0.871113	valid_1's auc: 0.785919
# [1500]	training's auc: 0.875328	valid_1's auc: 0.786468
# [1600]	training's auc: 0.879369	valid_1's auc: 0.786773
# [1700]	training's auc: 0.883399	valid_1's auc: 0.787304
# [1800]	training's auc: 0.887273	valid_1's auc: 0.787546
# [1900]	training's auc: 0.891029	valid_1's auc: 0.787862
# [2000]	training's auc: 0.894475	valid_1's auc: 0.787934
# [2100]	training's auc: 0.897937	valid_1's auc: 0.788167
# [2200]	training's auc: 0.901325	valid_1's auc: 0.788078
# Early stopping, best iteration is:
# [2155]	training's auc: 0.899805	valid_1's auc: 0.788348
# Fold 13 AUC : 0.788348
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758929	valid_1's auc: 0.747922
# [200]	training's auc: 0.780682	valid_1's auc: 0.762827
# [300]	training's auc: 0.797942	valid_1's auc: 0.774961
# [400]	training's auc: 0.809448	valid_1's auc: 0.78142
# [500]	training's auc: 0.818673	valid_1's auc: 0.785846
# [600]	training's auc: 0.826569	valid_1's auc: 0.788839
# [700]	training's auc: 0.83362	valid_1's auc: 0.790648
# [800]	training's auc: 0.840216	valid_1's auc: 0.79224
# [900]	training's auc: 0.846159	valid_1's auc: 0.79329
# [1000]	training's auc: 0.851704	valid_1's auc: 0.794605
# [1100]	training's auc: 0.856817	valid_1's auc: 0.794902
# [1200]	training's auc: 0.861955	valid_1's auc: 0.79545
# [1300]	training's auc: 0.866679	valid_1's auc: 0.79581
# [1400]	training's auc: 0.871264	valid_1's auc: 0.796103
# [1500]	training's auc: 0.87549	valid_1's auc: 0.796279
# [1600]	training's auc: 0.879365	valid_1's auc: 0.796211
# Early stopping, best iteration is:
# [1532]	training's auc: 0.876793	valid_1's auc: 0.796418
# Fold 14 AUC : 0.796418
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759436	valid_1's auc: 0.74028
# [200]	training's auc: 0.78072	valid_1's auc: 0.757738
# [300]	training's auc: 0.797982	valid_1's auc: 0.771475
# [400]	training's auc: 0.809556	valid_1's auc: 0.778554
# [500]	training's auc: 0.818677	valid_1's auc: 0.78252
# [600]	training's auc: 0.826735	valid_1's auc: 0.785198
# [700]	training's auc: 0.833862	valid_1's auc: 0.787093
# [800]	training's auc: 0.84014	valid_1's auc: 0.787966
# [900]	training's auc: 0.845888	valid_1's auc: 0.788748
# [1000]	training's auc: 0.851257	valid_1's auc: 0.789736
# [1100]	training's auc: 0.856396	valid_1's auc: 0.790396
# [1200]	training's auc: 0.861015	valid_1's auc: 0.790617
# [1300]	training's auc: 0.865772	valid_1's auc: 0.791076
# [1400]	training's auc: 0.870235	valid_1's auc: 0.791561
# [1500]	training's auc: 0.874549	valid_1's auc: 0.791644
# [1600]	training's auc: 0.878789	valid_1's auc: 0.792059
# [1700]	training's auc: 0.882849	valid_1's auc: 0.792016
# Early stopping, best iteration is:
# [1610]	training's auc: 0.879138	valid_1's auc: 0.792092
# Fold 15 AUC : 0.792092
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758623	valid_1's auc: 0.749059
# [200]	training's auc: 0.780251	valid_1's auc: 0.765648
# [300]	training's auc: 0.797741	valid_1's auc: 0.778294
# [400]	training's auc: 0.809265	valid_1's auc: 0.784234
# [500]	training's auc: 0.81856	valid_1's auc: 0.788086
# [600]	training's auc: 0.826615	valid_1's auc: 0.79031
# [700]	training's auc: 0.833843	valid_1's auc: 0.791959
# [800]	training's auc: 0.840267	valid_1's auc: 0.793287
# [900]	training's auc: 0.846206	valid_1's auc: 0.794036
# [1000]	training's auc: 0.851486	valid_1's auc: 0.794373
# [1100]	training's auc: 0.856817	valid_1's auc: 0.794668
# [1200]	training's auc: 0.861704	valid_1's auc: 0.795075
# [1300]	training's auc: 0.86635	valid_1's auc: 0.795333
# [1400]	training's auc: 0.87082	valid_1's auc: 0.795466
# [1500]	training's auc: 0.875201	valid_1's auc: 0.795685
# Early stopping, best iteration is:
# [1477]	training's auc: 0.874149	valid_1's auc: 0.795755
# Fold 16 AUC : 0.795755
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758561	valid_1's auc: 0.758687
# [200]	training's auc: 0.780243	valid_1's auc: 0.773326
# [300]	training's auc: 0.797674	valid_1's auc: 0.7837
# [400]	training's auc: 0.809457	valid_1's auc: 0.789672
# [500]	training's auc: 0.818842	valid_1's auc: 0.793294
# [600]	training's auc: 0.826822	valid_1's auc: 0.795151
# [700]	training's auc: 0.833792	valid_1's auc: 0.796363
# [800]	training's auc: 0.84024	valid_1's auc: 0.797166
# [900]	training's auc: 0.846381	valid_1's auc: 0.797485
# [1000]	training's auc: 0.851769	valid_1's auc: 0.797527
# [1100]	training's auc: 0.857189	valid_1's auc: 0.798115
# [1200]	training's auc: 0.862047	valid_1's auc: 0.798035
# Early stopping, best iteration is:
# [1109]	training's auc: 0.857626	valid_1's auc: 0.798196
# Fold 17 AUC : 0.798196
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.75838	valid_1's auc: 0.759492
# [200]	training's auc: 0.780359	valid_1's auc: 0.777197
# [300]	training's auc: 0.797528	valid_1's auc: 0.788852
# [400]	training's auc: 0.809108	valid_1's auc: 0.794479
# [500]	training's auc: 0.8184	valid_1's auc: 0.798044
# [600]	training's auc: 0.826335	valid_1's auc: 0.799914
# [700]	training's auc: 0.833681	valid_1's auc: 0.801772
# [800]	training's auc: 0.839866	valid_1's auc: 0.802237
# [900]	training's auc: 0.845677	valid_1's auc: 0.802927
# [1000]	training's auc: 0.85105	valid_1's auc: 0.803176
# [1100]	training's auc: 0.856034	valid_1's auc: 0.803146
# [1200]	training's auc: 0.860784	valid_1's auc: 0.803221
# [1300]	training's auc: 0.865551	valid_1's auc: 0.803433
# [1400]	training's auc: 0.870079	valid_1's auc: 0.803481
# Early stopping, best iteration is:
# [1337]	training's auc: 0.867205	valid_1's auc: 0.803557
# Fold 18 AUC : 0.803557
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759201	valid_1's auc: 0.750082
# [200]	training's auc: 0.780764	valid_1's auc: 0.764752
# [300]	training's auc: 0.798057	valid_1's auc: 0.775775
# [400]	training's auc: 0.809727	valid_1's auc: 0.779988
# [500]	training's auc: 0.81899	valid_1's auc: 0.783142
# [600]	training's auc: 0.826981	valid_1's auc: 0.784968
# [700]	training's auc: 0.834047	valid_1's auc: 0.786153
# [800]	training's auc: 0.840541	valid_1's auc: 0.786655
# [900]	training's auc: 0.846681	valid_1's auc: 0.786897
# [1000]	training's auc: 0.852253	valid_1's auc: 0.787185
# Early stopping, best iteration is:
# [981]	training's auc: 0.851238	valid_1's auc: 0.787275
# Fold 19 AUC : 0.787275
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758957	valid_1's auc: 0.749594
# [200]	training's auc: 0.780757	valid_1's auc: 0.767185
# [300]	training's auc: 0.797576	valid_1's auc: 0.778096
# [400]	training's auc: 0.809353	valid_1's auc: 0.784773
# [500]	training's auc: 0.81853	valid_1's auc: 0.78829
# [600]	training's auc: 0.826532	valid_1's auc: 0.790678
# [700]	training's auc: 0.833545	valid_1's auc: 0.792578
# [800]	training's auc: 0.84006	valid_1's auc: 0.793682
# [900]	training's auc: 0.845978	valid_1's auc: 0.794318
# [1000]	training's auc: 0.851442	valid_1's auc: 0.794992
# [1100]	training's auc: 0.856704	valid_1's auc: 0.795274
# [1200]	training's auc: 0.861564	valid_1's auc: 0.795802
# [1300]	training's auc: 0.866396	valid_1's auc: 0.796462
# [1400]	training's auc: 0.870904	valid_1's auc: 0.797168
# [1500]	training's auc: 0.875202	valid_1's auc: 0.797739
# [1600]	training's auc: 0.879262	valid_1's auc: 0.79824
# [1700]	training's auc: 0.883163	valid_1's auc: 0.798354
# Early stopping, best iteration is:
# [1692]	training's auc: 0.882864	valid_1's auc: 0.798457
# Fold 20 AUC : 0.798457
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759208	valid_1's auc: 0.747243
# [200]	training's auc: 0.780775	valid_1's auc: 0.761069
# [300]	training's auc: 0.798088	valid_1's auc: 0.770444
# [400]	training's auc: 0.809773	valid_1's auc: 0.775482
# [500]	training's auc: 0.818979	valid_1's auc: 0.778137
# [600]	training's auc: 0.827115	valid_1's auc: 0.779399
# [700]	training's auc: 0.83424	valid_1's auc: 0.780844
# [800]	training's auc: 0.840672	valid_1's auc: 0.781536
# [900]	training's auc: 0.846428	valid_1's auc: 0.782119
# [1000]	training's auc: 0.851837	valid_1's auc: 0.782462
# [1100]	training's auc: 0.857035	valid_1's auc: 0.782794
# [1200]	training's auc: 0.862041	valid_1's auc: 0.783061
# [1300]	training's auc: 0.866706	valid_1's auc: 0.78341
# [1400]	training's auc: 0.871172	valid_1's auc: 0.783509
# [1500]	training's auc: 0.875459	valid_1's auc: 0.783456
# [1600]	training's auc: 0.879404	valid_1's auc: 0.783642
# Early stopping, best iteration is:
# [1578]	training's auc: 0.878579	valid_1's auc: 0.783867
# Fold 21 AUC : 0.783867
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.75912	valid_1's auc: 0.754667
# [200]	training's auc: 0.780629	valid_1's auc: 0.769184
# [300]	training's auc: 0.797884	valid_1's auc: 0.780823
# [400]	training's auc: 0.809459	valid_1's auc: 0.785466
# [500]	training's auc: 0.818756	valid_1's auc: 0.788041
# [600]	training's auc: 0.826864	valid_1's auc: 0.789591
# [700]	training's auc: 0.834054	valid_1's auc: 0.790666
# [800]	training's auc: 0.840376	valid_1's auc: 0.791522
# [900]	training's auc: 0.846173	valid_1's auc: 0.79192
# [1000]	training's auc: 0.851784	valid_1's auc: 0.792611
# [1100]	training's auc: 0.85673	valid_1's auc: 0.79291
# [1200]	training's auc: 0.861669	valid_1's auc: 0.793064
# [1300]	training's auc: 0.86658	valid_1's auc: 0.793123
# [1400]	training's auc: 0.871118	valid_1's auc: 0.793443
# [1500]	training's auc: 0.875261	valid_1's auc: 0.793479
# [1600]	training's auc: 0.879525	valid_1's auc: 0.793748
# Early stopping, best iteration is:
# [1580]	training's auc: 0.878671	valid_1's auc: 0.793782
# Fold 22 AUC : 0.793782
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758668	valid_1's auc: 0.758
# [200]	training's auc: 0.780233	valid_1's auc: 0.773478
# [300]	training's auc: 0.797521	valid_1's auc: 0.783032
# [400]	training's auc: 0.809238	valid_1's auc: 0.787127
# [500]	training's auc: 0.818639	valid_1's auc: 0.789884
# [600]	training's auc: 0.826823	valid_1's auc: 0.791828
# [700]	training's auc: 0.83398	valid_1's auc: 0.792945
# [800]	training's auc: 0.840374	valid_1's auc: 0.793835
# [900]	training's auc: 0.846589	valid_1's auc: 0.794868
# [1000]	training's auc: 0.852044	valid_1's auc: 0.795158
# [1100]	training's auc: 0.856975	valid_1's auc: 0.795672
# [1200]	training's auc: 0.86199	valid_1's auc: 0.795889
# [1300]	training's auc: 0.866686	valid_1's auc: 0.796063
# [1400]	training's auc: 0.87111	valid_1's auc: 0.796285
# [1500]	training's auc: 0.87551	valid_1's auc: 0.796546
# [1600]	training's auc: 0.879566	valid_1's auc: 0.796752
# [1700]	training's auc: 0.88352	valid_1's auc: 0.796449
# Early stopping, best iteration is:
# [1639]	training's auc: 0.881199	valid_1's auc: 0.796786
# Fold 23 AUC : 0.796786
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759111	valid_1's auc: 0.749966
# [200]	training's auc: 0.780824	valid_1's auc: 0.763949
# [300]	training's auc: 0.798004	valid_1's auc: 0.775131
# [400]	training's auc: 0.809608	valid_1's auc: 0.780576
# [500]	training's auc: 0.818684	valid_1's auc: 0.783526
# [600]	training's auc: 0.826836	valid_1's auc: 0.785918
# [700]	training's auc: 0.833835	valid_1's auc: 0.786796
# [800]	training's auc: 0.840397	valid_1's auc: 0.787683
# [900]	training's auc: 0.846107	valid_1's auc: 0.788281
# [1000]	training's auc: 0.851544	valid_1's auc: 0.788829
# [1100]	training's auc: 0.856997	valid_1's auc: 0.789135
# [1200]	training's auc: 0.861697	valid_1's auc: 0.789373
# [1300]	training's auc: 0.86631	valid_1's auc: 0.789714
# [1400]	training's auc: 0.870646	valid_1's auc: 0.790252
# [1500]	training's auc: 0.874916	valid_1's auc: 0.790721
# [1600]	training's auc: 0.879012	valid_1's auc: 0.790695
# Early stopping, best iteration is:
# [1556]	training's auc: 0.877253	valid_1's auc: 0.790912
# Fold 24 AUC : 0.790912
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.759137	valid_1's auc: 0.747579
# [200]	training's auc: 0.780549	valid_1's auc: 0.76575
# [300]	training's auc: 0.797412	valid_1's auc: 0.778128
# [400]	training's auc: 0.80916	valid_1's auc: 0.784574
# [500]	training's auc: 0.818551	valid_1's auc: 0.788502
# [600]	training's auc: 0.826608	valid_1's auc: 0.791445
# [700]	training's auc: 0.83381	valid_1's auc: 0.792659
# [800]	training's auc: 0.840321	valid_1's auc: 0.79369
# [900]	training's auc: 0.846481	valid_1's auc: 0.794561
# [1000]	training's auc: 0.851986	valid_1's auc: 0.79497
# [1100]	training's auc: 0.857014	valid_1's auc: 0.795574
# [1200]	training's auc: 0.861962	valid_1's auc: 0.796004
# [1300]	training's auc: 0.86666	valid_1's auc: 0.796407
# [1400]	training's auc: 0.87096	valid_1's auc: 0.796654
# [1500]	training's auc: 0.875493	valid_1's auc: 0.796885
# [1600]	training's auc: 0.879737	valid_1's auc: 0.797053
# [1700]	training's auc: 0.883802	valid_1's auc: 0.797203
# [1800]	training's auc: 0.88769	valid_1's auc: 0.797404
# Early stopping, best iteration is:
# [1754]	training's auc: 0.885952	valid_1's auc: 0.797464
# Fold 25 AUC : 0.797464
# Full AUC score 0.793527

# %%
sub.to_csv('./kageyama_feature_matrix_25cv_tuned_by_Ivan_sub_noIDs.csv', index=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

def display_importances(feature_importance_df_):
    # Plot feature importances
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:50].index
    
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    
    plt.figure(figsize=(8,10))
    sns.barplot(x="importance", y="feature", 
                data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()

# %%
display_importances(feature_importance_df)

# %%
time.time() - st
# Out:
# 22832.405517101288

# %%
feature_importances = feature_importance_df[["feature", "importance"]].groupby("feature").mean()

def norm_feature_importances(df, threshold = 0.95):
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])
    
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df

norm_feature_importances = norm_feature_importances(feature_importances)

# Threshold for cumulative importance
threshold = 0.95

# Extract the features to keep
unimportant_features = list(norm_feature_importances[norm_feature_importances['cumulative_importance'] >= threshold]['feature'])

df = pd.read_csv('./new_feature_by_kageyama_feature_matrix_noIDs.csv')
df = df.drop(unimportant_features, axis=1)
df.to_csv('./new_feature_by_kageyama_feature_matrix_noIDs_delunimportant.csv',  index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17bcd867f75e> in <module>()
# ----> 1 feature_importances = feature_importance_df[["feature", "importance"]].groupby("feature").mean()
#       2
#       3 def norm_feature_importances(df, threshold = 0.95):
#       4
#       5     # Sort features according to importance
#
# NameError: name 'feature_importance_df' is not defined

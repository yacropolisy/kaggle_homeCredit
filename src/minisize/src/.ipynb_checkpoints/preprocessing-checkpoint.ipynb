# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
import time

import gc

# %%
# File system manangement
import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('../input/application_train.csv')
test_df = pd.read_csv('../input/application_test.csv')
bureau = pd.read_csv('../input/bureau.csv').sort_values(['SK_ID_CURR', 'SK_ID_BUREAU']).reset_index(drop = True)
bureau_balance = pd.read_csv('../input/bureau_balance.csv').sort_values('SK_ID_BUREAU').reset_index(drop = True)
cash = pd.read_csv('../input/POS_CASH_balance.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True)
credit = pd.read_csv('../input/credit_card_balance.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True)
previous = pd.read_csv('../input/previous_application.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True)
installments = pd.read_csv('../input/installments_payments.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True)

# %%
train_df['is_train'] = True
test_df['is_train'] = False
all_df = pd.concat([train_df, test_df])

# all_df['DAYS_EMPLOYED_ANOM'] = all_df["DAYS_EMPLOYED"] == 365243
all_df["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace = True)

# %%
# featuretools for automated feature engineering
import featuretools as ft

# %%
es = ft.EntitySet(id = 'clients')

# Entities with a unique index
es = es.entity_from_dataframe(entity_id = 'app', dataframe = train_df, index = 'SK_ID_CURR')

es = es.entity_from_dataframe(entity_id = 'bureau', dataframe = bureau, index = 'SK_ID_BUREAU')

es = es.entity_from_dataframe(entity_id = 'previous', dataframe = previous, index = 'SK_ID_PREV')

# Entities that do not have a unique index
es = es.entity_from_dataframe(entity_id = 'bureau_balance', dataframe = bureau_balance, 
                              make_index = True, index = 'bureaubalance_index')

es = es.entity_from_dataframe(entity_id = 'cash', dataframe = cash, 
                              make_index = True, index = 'cash_index')

es = es.entity_from_dataframe(entity_id = 'installments', dataframe = installments,
                              make_index = True, index = 'installments_index')

es = es.entity_from_dataframe(entity_id = 'credit', dataframe = credit,
                              make_index = True, index = 'credit_index')

# %%
# Relationship between app and bureau
r_app_bureau = ft.Relationship(es['app']['SK_ID_CURR'], es['bureau']['SK_ID_CURR'])

# Relationship between bureau and bureau balance
r_bureau_balance = ft.Relationship(es['bureau']['SK_ID_BUREAU'], es['bureau_balance']['SK_ID_BUREAU'])

# Relationship between current app and previous apps
r_app_previous = ft.Relationship(es['app']['SK_ID_CURR'], es['previous']['SK_ID_CURR'])

# Relationships between previous apps and cash, installments, and credit
r_previous_cash = ft.Relationship(es['previous']['SK_ID_PREV'], es['cash']['SK_ID_PREV'])
r_previous_installments = ft.Relationship(es['previous']['SK_ID_PREV'], es['installments']['SK_ID_PREV'])
r_previous_credit = ft.Relationship(es['previous']['SK_ID_PREV'], es['credit']['SK_ID_PREV'])

# %%
# Add in the defined relationships
es = es.add_relationships([r_app_bureau, r_bureau_balance, r_app_previous,
                           r_previous_cash, r_previous_installments, r_previous_credit])
# Print out the EntitySet
es
# Out:
# Entityset: clients
#   Entities:
#     app [Rows: 50000, Columns: 123]
#     bureau [Rows: 289257, Columns: 17]
#     previous [Rows: 282870, Columns: 37]
#     bureau_balance [Rows: 4288064, Columns: 4]
#     cash [Rows: 1687552, Columns: 9]
#     installments [Rows: 2295557, Columns: 9]
#     credit [Rows: 650563, Columns: 24]
#   Relationships:
#     bureau.SK_ID_CURR -> app.SK_ID_CURR
#     bureau_balance.SK_ID_BUREAU -> bureau.SK_ID_BUREAU
#     previous.SK_ID_CURR -> app.SK_ID_CURR
#     cash.SK_ID_PREV -> previous.SK_ID_PREV
#     installments.SK_ID_PREV -> previous.SK_ID_PREV
#     credit.SK_ID_PREV -> previous.SK_ID_PREV

# %%
# List the primitives in a dataframe
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation']
# Out:
#                 name         type  \
# 0                any  aggregation
# 1         num_unique  aggregation
# 2               last  aggregation
# 3           num_true  aggregation
# 4                max  aggregation
# 5               mode  aggregation
# 6                std  aggregation
# 7              trend  aggregation
# 8                min  aggregation
# 9               mean  aggregation
# 10      percent_true  aggregation
# 11              skew  aggregation
# 12   time_since_last  aggregation
# 13               sum  aggregation
# 14            median  aggregation
# 15             count  aggregation
# 16  avg_time_between  aggregation
# 17               all  aggregation
# 18     n_most_common  aggregation
#
#                                                                 description
# 0                                              Test if any value is 'True'.
# 1                       Returns the number of unique categorical variables.
# 2                                                   Returns the last value.
# 3                           Finds the number of 'True' values in a boolean.
# 4                    Finds the maximum non-null value of a numeric feature.
# 5                   Finds the most common element in a categorical feature.
# 6   Finds the standard deviation of a numeric feature ignoring null values.
# 7            Calculates the slope of the linear trend of variable overtime.
# 8                    Finds the minimum non-null value of a numeric feature.
# 9                          Computes the average value of a numeric feature.
# 10                 Finds the percent of 'True' values in a boolean feature.
# 11                                     Computes the skewness of a data set.
# 12                                        Time since last related instance.
# 13           Counts the number of elements of a numeric or boolean feature.
# 14          Finds the median value of any feature with well-ordered values.
# 15                                    Counts the number of non null values.
# 16                    Computes the average time between consecutive events.
# 17                                           Test if all values are 'True'.
# 18               Finds the N most common elements in a categorical feature.

# %%
primitives[primitives['type'] == 'transform']
# Out:
#                    name       type  \
# 19               months  transform
# 20              cum_min  transform
# 21               divide  transform
# 22                weeks  transform
# 23            cum_count  transform
# 24                 hour  transform
# 25             subtract  transform
# 26                 isin  transform
# 27              minutes  transform
# 28              cum_sum  transform
# 29               second  transform
# 30                  day  transform
# 31           time_since  transform
# 32                  and  transform
# 33             latitude  transform
# 34           characters  transform
# 35              seconds  transform
# 36             absolute  transform
# 37                  not  transform
# 38              weekend  transform
# 39                 year  transform
# 40                  mod  transform
# 41                month  transform
# 42              cum_max  transform
# 43             multiply  transform
# 44                 week  transform
# 45             cum_mean  transform
# 46                 days  transform
# 47                  add  transform
# 48           days_since  transform
# 49                hours  transform
# 50               minute  transform
# 51                   or  transform
# 52            longitude  transform
# 53             numwords  transform
# 54  time_since_previous  transform
# 55           percentile  transform
# 56              weekday  transform
# 57              is_null  transform
# 58                 diff  transform
# 59            haversine  transform
# 60                years  transform
# 61               negate  transform
#
#                                                                                            description
# 19                                            Transform a Timedelta feature into the number of months.
# 20     Calculates the min of previous values of an instance for each value in a time-dependent entity.
# 21                                              Creates a transform feature that divides two features.
# 22                                             Transform a Timedelta feature into the number of weeks.
# 23  Calculates the number of previous values of an instance for each value in a time-dependent entity.
# 24                                                         Transform a Datetime feature into the hour.
# 25                                            Creates a transform feature that subtracts two features.
# 26                        For each value of the base feature, checks whether it is in a provided list.
# 27                                           Transform a Timedelta feature into the number of minutes.
# 28     Calculates the sum of previous values of an instance for each value in a time-dependent entity.
# 29                                                       Transform a Datetime feature into the second.
# 30                                                          Transform a Datetime feature into the day.
# 31                                                              Calculates time since the cutoff time.
# 32                                        For two boolean values, determine if both values are 'True'.
# 33                                                  Returns the first value of the tuple base feature.
# 34                                                            Return the characters in a given string.
# 35                                           Transform a Timedelta feature into the number of seconds.
# 36                                                                     Absolute value of base feature.
# 37                                      For each value of the base feature, negates the boolean value.
# 38                                             Transform Datetime feature into the boolean of Weekend.
# 39                                                         Transform a Datetime feature into the year.
# 40                                              Creates a transform feature that divides two features.
# 41                                                        Transform a Datetime feature into the month.
# 42     Calculates the max of previous values of an instance for each value in a time-dependent entity.
# 43                                            Creates a transform feature that multplies two features.
# 44                                                         Transform a Datetime feature into the week.
# 45    Calculates the mean of previous values of an instance for each value in a time-dependent entity.
# 46                                              Transform a Timedelta feature into the number of days.
# 47                                                 Creates a transform feature that adds two features.
# 48                           For each value of the base feature, compute the number of days between it
# 49                                             Transform a Timedelta feature into the number of hours.
# 50                                                       Transform a Datetime feature into the minute.
# 51                                           For two boolean values, determine if one value is 'True'.
# 52                                                 Returns the second value on the tuple base feature.
# 53                                         Returns the words in a given string by counting the spaces.
# 54                                                       Compute the time since the previous instance.
# 55                           For each value of the base feature, determines the percentile in relation
# 56                                             Transform Datetime feature into the boolean of Weekday.
# 57                                     For each value of base feature, return 'True' if value is null.
# 58                  Compute the difference between the value of a base feature and the previous value.
# 59           Calculate the approximate haversine distance in miles between two LatLong variable types.
# 60                                             Transform a Timedelta feature into the number of years.
# 61                                                 Creates a transform feature that negates a feature.

# %%
# DFS with default primitives
default_agg_primitives = ["std", "max", "skew", "min", "mean", "count", "percent_true", "num_unique", "mode"]

feature_matrix, feature_names = ft.dfs(entityset = es, target_entity = 'app',
#                                        trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives, 
                                        max_depth = 2, features_only=False, verbose = True,
                                      n_jobs = -1)
feature_matrix.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-19851de63208> in <module>()
#       6                                        agg_primitives=default_agg_primitives,
#       7                                         max_depth = 2, features_only=False, verbose = True,
# ----> 8                                       n_jobs = -1)
#       9 feature_matrix.head(10)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/synthesis/dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, n_jobs, dask_kwargs, verbose)
#     182                                       seed_features=seed_features)
#     183
# --> 184     features = dfs_object.build_features(verbose=verbose)
#     185
#     186     if features_only:
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in build_features(self, variable_types, verbose)
#     214         self.where_clauses = defaultdict(set)
#     215         self._run_dfs(self.es[self.target_entity_id], [],
# --> 216                       all_features, max_depth=self.max_depth)
#     217
#     218         new_features = list(all_features[self.target_entity_id].values())
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in _run_dfs(self, entity, entity_path, all_features, max_depth)
#     361         """
#     362         self._build_transform_features(
# --> 363             all_features, entity, max_depth=max_depth)
#     364
#     365         """
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in _build_transform_features(self, all_features, entity, max_depth)
#     493             new_max_depth = max_depth - 1
#     494
# --> 495         self._add_identity_features(all_features, entity)
#     496
#     497         for trans_prim in self.trans_primitives:
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in _add_identity_features(self, all_features, entity)
#     448             if v.id in ignore_variables:
#     449                 continue
# --> 450             new_f = IdentityFeature(variable=v)
#     451             self._handle_new_feature(all_features=all_features,
#     452                                      new_feature=new_f)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/primitives/primitive_base.py in __init__(self, variable)
#     433         self.return_type = type(variable)
#     434         self.base_feature = None
# --> 435         super(IdentityFeature, self).__init__(variable.entity, [])
#     436
#     437     def generate_name(self):
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/primitives/primitive_base.py in __init__(self, entity, base_features, **kwargs)
#      65
#      66         self.entity_id = entity.id
# ---> 67         self.entityset = entity.entityset.metadata
#      68
#      69         # P TODO: where should this logic go?
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/entityset/entityset.py in metadata(self)
#     183         '''
#     184         new_metadata = self.from_metadata(self.create_metadata_dict(),
# --> 185                                           data_root=None)
#     186         if self._metadata is None:
#     187             self._metadata = new_metadata
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/entityset/entityset.py in from_metadata(cls, metadata, data_root)
#     250         set_last_time_indexes = False
#     251         for eid, entity in metadata['entity_dict'].items():
# --> 252             df, variable_types = cls._load_dummy_entity_data_and_variable_types(entity)
#     253             if data_root is not None:
#     254                 df = load_entity_data(entity, data_root)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/featuretools/entityset/entityset.py in _load_dummy_entity_data_and_variable_types(cls, metadata)
#    1395                 defaults.append(vtypes.DEFAULT_DTYPE_VALUES[object])
#    1396             columns.append(vid)
# -> 1397         df = pd.DataFrame({c: [d] for c, d in zip(columns, defaults)}).head(0)
#    1398         return df, variable_types
#    1399
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6166
#    6167     # don't force copy because getting jammed in an ndarray anyway
# -> 6168     arrays = _homogenize(arrays, index, dtype)
#    6169
#    6170     # from BlockManager perspective
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/frame.py in _homogenize(data, index, dtype)
#    6475                 v = lib.fast_multiget(v, oindex.values, default=np.nan)
#    6476             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 6477                                 raise_cast_failure=False)
#    6478
#    6479         homogenized.append(v)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3216
#    3217         else:
# -> 3218             subarr = maybe_convert_platform(data)
#    3219
#    3220         subarr = maybe_cast_to_datetime(subarr, dtype)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/kaggle/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in maybe_convert_platform(values)
#      45         if hasattr(values, '_values'):
#      46             values = values._values
# ---> 47         values = lib.maybe_convert_objects(values)
#      48
#      49     return values
#
# KeyboardInterrupt:

# %%
# DFS with default primitives
default_agg_primitives = ["std", "max", "min", "mean", "count", "mode"]

feature_matrix, feature_names = ft.dfs(entityset = es, target_entity = 'app',
#                                                                     trans_primitives = default_trans_primitives,
                                                                    agg_primitives=default_agg_primitives, 
                                                                    max_depth = 2, features_only=False, verbose = True,
                                                                    n_jobs = -1)
feature_matrix.head(10)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_feats = [f for f in all_df.columns if all_df[f].dtype == 'object']
for col in tqdm(categorical_feats):
    all_df[col] = all_df[col].astype('str')
    le.fit(all_df[col])
    all_df[col] = le.transform(all_df[col])

train_df = all_df[all_df['is_train'] == True].drop('is_train', axis=1)
test_df = all_df[all_df['is_train'] == False].drop('is_train', axis=1).drop('TARGET', axis=1)

# del all_df
# gc.collect()

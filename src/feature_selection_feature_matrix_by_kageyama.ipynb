# %% [markdown]
# # feature selection
# reference : https://www.kaggle.com/willkoehrsen/introduction-to-feature-selection

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier

import time
import gc
from tqdm import tqdm

# %%
st = time.time()
df = pd.read_csv('./new_feature_by_kageyama_feature_matrix.csv')
time.time() - st
# Out:
# 124.8741147518158

# %% [markdown]
# # drop IDs

# %%
id_columns = []
for c in df.columns:
    if 'SK_ID' in c :
        print(c)
        if c != 'SK_ID_CURR':
            id_columns.append(c)
df = df.drop(id_columns, axis = 1)
# Out:
# SK_ID_CURR
# STD(installments.SK_ID_CURR)
# MAX(installments.SK_ID_CURR)
# SKEW(installments.SK_ID_CURR)
# MIN(installments.SK_ID_CURR)
# MEAN(installments.SK_ID_CURR)
# STD(cash.SK_ID_CURR)
# MAX(cash.SK_ID_CURR)
# SKEW(cash.SK_ID_CURR)
# MIN(cash.SK_ID_CURR)
# MEAN(cash.SK_ID_CURR)
# STD(credit.SK_ID_CURR)
# MAX(credit.SK_ID_CURR)
# SKEW(credit.SK_ID_CURR)
# MIN(credit.SK_ID_CURR)
# MEAN(credit.SK_ID_CURR)
# STD(previous.MAX(installments.SK_ID_CURR))
# STD(previous.SKEW(installments.SK_ID_CURR))
# STD(previous.MIN(installments.SK_ID_CURR))
# STD(previous.MEAN(installments.SK_ID_CURR))
# STD(previous.MAX(cash.SK_ID_CURR))
# STD(previous.SKEW(cash.SK_ID_CURR))
# STD(previous.MIN(cash.SK_ID_CURR))
# STD(previous.MEAN(cash.SK_ID_CURR))
# STD(previous.MAX(credit.SK_ID_CURR))
# STD(previous.SKEW(credit.SK_ID_CURR))
# STD(previous.MIN(credit.SK_ID_CURR))
# STD(previous.MEAN(credit.SK_ID_CURR))
# MAX(previous.STD(installments.SK_ID_CURR))
# MAX(previous.SKEW(installments.SK_ID_CURR))
# MAX(previous.MIN(installments.SK_ID_CURR))
# MAX(previous.MEAN(installments.SK_ID_CURR))
# MAX(previous.STD(cash.SK_ID_CURR))
# MAX(previous.SKEW(cash.SK_ID_CURR))
# MAX(previous.MIN(cash.SK_ID_CURR))
# MAX(previous.MEAN(cash.SK_ID_CURR))
# MAX(previous.STD(credit.SK_ID_CURR))
# MAX(previous.SKEW(credit.SK_ID_CURR))
# MAX(previous.MIN(credit.SK_ID_CURR))
# MAX(previous.MEAN(credit.SK_ID_CURR))
# SKEW(previous.STD(installments.SK_ID_CURR))
# SKEW(previous.MAX(installments.SK_ID_CURR))
# SKEW(previous.MIN(installments.SK_ID_CURR))
# SKEW(previous.MEAN(installments.SK_ID_CURR))
# SKEW(previous.STD(cash.SK_ID_CURR))
# SKEW(previous.MAX(cash.SK_ID_CURR))
# SKEW(previous.MIN(cash.SK_ID_CURR))
# SKEW(previous.MEAN(cash.SK_ID_CURR))
# SKEW(previous.STD(credit.SK_ID_CURR))
# SKEW(previous.MAX(credit.SK_ID_CURR))
# SKEW(previous.MIN(credit.SK_ID_CURR))
# SKEW(previous.MEAN(credit.SK_ID_CURR))
# MIN(previous.STD(installments.SK_ID_CURR))
# MIN(previous.MAX(installments.SK_ID_CURR))
# MIN(previous.SKEW(installments.SK_ID_CURR))
# MIN(previous.MEAN(installments.SK_ID_CURR))
# MIN(previous.STD(cash.SK_ID_CURR))
# MIN(previous.MAX(cash.SK_ID_CURR))
# MIN(previous.SKEW(cash.SK_ID_CURR))
# MIN(previous.MEAN(cash.SK_ID_CURR))
# MIN(previous.STD(credit.SK_ID_CURR))
# MIN(previous.MAX(credit.SK_ID_CURR))
# MIN(previous.SKEW(credit.SK_ID_CURR))
# MIN(previous.MEAN(credit.SK_ID_CURR))
# MEAN(previous.STD(installments.SK_ID_CURR))
# MEAN(previous.MAX(installments.SK_ID_CURR))
# MEAN(previous.SKEW(installments.SK_ID_CURR))
# MEAN(previous.MIN(installments.SK_ID_CURR))
# MEAN(previous.MEAN(installments.SK_ID_CURR))
# MEAN(previous.STD(cash.SK_ID_CURR))
# MEAN(previous.MAX(cash.SK_ID_CURR))
# MEAN(previous.SKEW(cash.SK_ID_CURR))
# MEAN(previous.MIN(cash.SK_ID_CURR))
# MEAN(previous.MEAN(cash.SK_ID_CURR))
# MEAN(previous.STD(credit.SK_ID_CURR))
# MEAN(previous.MAX(credit.SK_ID_CURR))
# MEAN(previous.SKEW(credit.SK_ID_CURR))
# MEAN(previous.MIN(credit.SK_ID_CURR))
# MEAN(previous.MEAN(credit.SK_ID_CURR))

# %%
df.to_csv('new_feature_by_kageyama_feature_matrix_noIDs.csv', index = False)

# %% [markdown]
# # Remove missing values

# %%
train_df = df.loc[df['set'] == 'train'] .drop('set', axis = 1)
test_df = df.loc[df['set'] == 'test'] .drop(['set', 'TARGET'], axis=1)

print('Training set full shape: ', train_df.shape)
print('Testing set full shape: ' , test_df.shape)

# Train missing values (in percent)
train_missing = (train_df.isnull().sum() / len(train_df)).sort_values(ascending = False)
train_missing.head()

# Test missing values (in percent)
test_missing = (test_df.isnull().sum() / len(test_df)).sort_values(ascending = False)
test_missing.head()

# Identify missing values above threshold
train_missing = train_missing.index[train_missing > 0.75]
test_missing = test_missing.index[test_missing > 0.75]

all_missing = list(set(set(train_missing) | set(test_missing)))
print('There are %d columns with more than 75%% missing values' % len(all_missing))

# Need to save the labels because aligning will remove this column
train_labels = train_df["TARGET"]

train_df = train_df.drop(columns = all_missing)
test_df = test_df.drop(columns = all_missing)

print('Training set full shape: ', train_df.shape)
print('Testing set full shape: ' , test_df.shape)
# Out:
# Training set full shape:  (307507, 1352)
# Testing set full shape:  (48744, 1351)
# There are 266 columns with more than 75% missing values
# Training set full shape:  (307507, 1086)
# Testing set full shape:  (48744, 1085)

# %%
df = df.drop(all_missing, axis = 1)
df.to_csv('new_feature_by_kageyama_feature_matrix_noIDs_delmissing.csv', index = False)

# %%
df = df.drop('SK_ID_CURR', axis = 1)

# %% [markdown]
# # Lable Encoding

# %%
train_df = df.loc[df['set'] == 'train'] .drop('set', axis = 1)
test_df = df.loc[df['set'] == 'test'] .drop(['set', 'TARGET'], axis=1)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
categorical_feats = [f for f in df.columns if df[f].dtype == 'object']
for col in tqdm(categorical_feats):
    if col == 'set' :
        continue
    df[col] = df[col].astype('str')
    le.fit(df[col])
    df[col] = le.transform(df[col])
train_df = df.loc[df['set'] == 'train'] .drop('set', axis = 1)
test_df = df.loc[df['set'] == 'test'] .drop(['set', 'TARGET'], axis=1)

del df
gc.collect()
# Out:
# 100%|██████████| 39/39 [00:42<00:00,  1.08s/it]
# 36

# %%
print('Training shape: ', train_df.shape)
print('Testing shape: ', test_df.shape)
# Out:
# Training shape:  (307507, 1085)
# Testing shape:  (48744, 1084)

# %% [markdown]
# # make prediction

# %%
oof_preds = np.zeros(train_df.shape[0])
sub_preds = np.zeros(test_df.shape[0])

feature_importance_df = pd.DataFrame()
y = train_df['TARGET'].copy()
X = train_df.drop('TARGET', axis = 1)


feats =  list(X.columns)

folds = KFold(n_splits=25, shuffle=True, random_state=2018)
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(X)):
    train_X, train_y = X.iloc[trn_idx], y.iloc[trn_idx]
    valid_X, valid_y = X.iloc[val_idx], y.iloc[val_idx]

    clf = LGBMClassifier(
        n_estimators=4000,
        learning_rate=0.02,
        num_leaves=32,
        colsample_bytree=.8,
        subsample=.87,
        max_depth=8,
        reg_alpha=.0415,
        reg_lambda=.0735,
        min_split_gain=.02,
        min_child_weight=40,
        silent=-1,
        verbose=-1,
    )

    clf.fit(train_X, train_y, 
            eval_set= [(train_X, train_y), (valid_X, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100  #30
           )

    oof_preds[val_idx] = clf.predict_proba(valid_X, num_iteration=clf.best_iteration_)[:, 1]
    sub_preds += clf.predict_proba(test_df, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[val_idx])))
    del clf, train_X, train_y, valid_X, valid_y
    gc.collect()

print('Full AUC score %.6f' % roc_auc_score(y, oof_preds)) 

sub = pd.read_csv('../input/sample_submission.csv')
sub['TARGET'] = sub_preds
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758048	valid_1's auc: 0.75187
# [200]	training's auc: 0.780604	valid_1's auc: 0.765147
# [300]	training's auc: 0.797832	valid_1's auc: 0.774264
# [400]	training's auc: 0.809577	valid_1's auc: 0.779593
# [500]	training's auc: 0.818757	valid_1's auc: 0.782253
# [600]	training's auc: 0.82692	valid_1's auc: 0.78405
# [700]	training's auc: 0.834106	valid_1's auc: 0.785431
# [800]	training's auc: 0.840667	valid_1's auc: 0.7864
# [900]	training's auc: 0.846456	valid_1's auc: 0.787259
# [1000]	training's auc: 0.852181	valid_1's auc: 0.787761
# [1100]	training's auc: 0.857468	valid_1's auc: 0.788235
# [1200]	training's auc: 0.862355	valid_1's auc: 0.788393
# [1300]	training's auc: 0.866973	valid_1's auc: 0.788824
# [1400]	training's auc: 0.871449	valid_1's auc: 0.78919
# [1500]	training's auc: 0.875703	valid_1's auc: 0.789657
# [1600]	training's auc: 0.879908	valid_1's auc: 0.789538
# Early stopping, best iteration is:
# [1509]	training's auc: 0.876079	valid_1's auc: 0.789737
# Fold  1 AUC : 0.789737
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758129	valid_1's auc: 0.747989
# [200]	training's auc: 0.78022	valid_1's auc: 0.763523
# [300]	training's auc: 0.797695	valid_1's auc: 0.775105
# [400]	training's auc: 0.809328	valid_1's auc: 0.78108
# [500]	training's auc: 0.818643	valid_1's auc: 0.784948
# [600]	training's auc: 0.826543	valid_1's auc: 0.787565
# [700]	training's auc: 0.833712	valid_1's auc: 0.789667
# [800]	training's auc: 0.840202	valid_1's auc: 0.791297
# [900]	training's auc: 0.846128	valid_1's auc: 0.792468
# [1000]	training's auc: 0.851651	valid_1's auc: 0.793193
# [1100]	training's auc: 0.856684	valid_1's auc: 0.794119
# [1200]	training's auc: 0.861599	valid_1's auc: 0.794383
# [1300]	training's auc: 0.866327	valid_1's auc: 0.794898
# [1400]	training's auc: 0.870797	valid_1's auc: 0.795303
# [1500]	training's auc: 0.875125	valid_1's auc: 0.795853
# [1600]	training's auc: 0.879404	valid_1's auc: 0.796056
# Early stopping, best iteration is:
# [1562]	training's auc: 0.877821	valid_1's auc: 0.796161
# Fold  2 AUC : 0.796161
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758542	valid_1's auc: 0.748105
# [200]	training's auc: 0.780405	valid_1's auc: 0.763806
# [300]	training's auc: 0.797878	valid_1's auc: 0.773221
# [400]	training's auc: 0.80971	valid_1's auc: 0.777875
# [500]	training's auc: 0.818972	valid_1's auc: 0.77993
# [600]	training's auc: 0.827083	valid_1's auc: 0.781312
# [700]	training's auc: 0.834121	valid_1's auc: 0.782201
# [800]	training's auc: 0.840693	valid_1's auc: 0.783086
# [900]	training's auc: 0.84671	valid_1's auc: 0.783878
# [1000]	training's auc: 0.852439	valid_1's auc: 0.784612
# [1100]	training's auc: 0.8576	valid_1's auc: 0.785124
# [1200]	training's auc: 0.862474	valid_1's auc: 0.785388
# [1300]	training's auc: 0.867033	valid_1's auc: 0.78565
# [1400]	training's auc: 0.87145	valid_1's auc: 0.785841
# [1500]	training's auc: 0.875859	valid_1's auc: 0.785894
# [1600]	training's auc: 0.879954	valid_1's auc: 0.786373
# [1700]	training's auc: 0.883977	valid_1's auc: 0.786589
# [1800]	training's auc: 0.887931	valid_1's auc: 0.786296
# Early stopping, best iteration is:
# [1700]	training's auc: 0.883977	valid_1's auc: 0.786589
# Fold  3 AUC : 0.786589
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758518	valid_1's auc: 0.742278
# [200]	training's auc: 0.78031	valid_1's auc: 0.757594
# [300]	training's auc: 0.797786	valid_1's auc: 0.768237
# [400]	training's auc: 0.809417	valid_1's auc: 0.773992
# [500]	training's auc: 0.818705	valid_1's auc: 0.777325
# [600]	training's auc: 0.82681	valid_1's auc: 0.779217
# [700]	training's auc: 0.834061	valid_1's auc: 0.780869
# [800]	training's auc: 0.840625	valid_1's auc: 0.782167
# [900]	training's auc: 0.846528	valid_1's auc: 0.78304
# [1000]	training's auc: 0.851798	valid_1's auc: 0.78342
# [1100]	training's auc: 0.856896	valid_1's auc: 0.783989
# [1200]	training's auc: 0.861876	valid_1's auc: 0.784483
# [1300]	training's auc: 0.866519	valid_1's auc: 0.784769
# [1400]	training's auc: 0.871102	valid_1's auc: 0.785218
# [1500]	training's auc: 0.875494	valid_1's auc: 0.785267
# [1600]	training's auc: 0.879586	valid_1's auc: 0.785087
# Early stopping, best iteration is:
# [1516]	training's auc: 0.876094	valid_1's auc: 0.785374
# Fold  4 AUC : 0.785374
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758336	valid_1's auc: 0.751794
# [200]	training's auc: 0.780257	valid_1's auc: 0.768015
# [300]	training's auc: 0.7979	valid_1's auc: 0.779009
# [400]	training's auc: 0.809522	valid_1's auc: 0.784155
# [500]	training's auc: 0.818813	valid_1's auc: 0.78724
# [600]	training's auc: 0.826878	valid_1's auc: 0.789574
# [700]	training's auc: 0.834185	valid_1's auc: 0.790855
# [800]	training's auc: 0.840636	valid_1's auc: 0.7924
# [900]	training's auc: 0.846601	valid_1's auc: 0.792941
# [1000]	training's auc: 0.851854	valid_1's auc: 0.793359
# [1100]	training's auc: 0.856777	valid_1's auc: 0.794088
# [1200]	training's auc: 0.861953	valid_1's auc: 0.794681
# [1300]	training's auc: 0.866615	valid_1's auc: 0.794588
# Early stopping, best iteration is:
# [1204]	training's auc: 0.862151	valid_1's auc: 0.794737
# Fold  5 AUC : 0.794737
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757938	valid_1's auc: 0.752322
# [200]	training's auc: 0.780095	valid_1's auc: 0.768886
# [300]	training's auc: 0.797576	valid_1's auc: 0.78102
# [400]	training's auc: 0.809178	valid_1's auc: 0.787248
# [500]	training's auc: 0.818519	valid_1's auc: 0.791287
# [600]	training's auc: 0.826715	valid_1's auc: 0.793834
# [700]	training's auc: 0.833843	valid_1's auc: 0.795559
# [800]	training's auc: 0.840173	valid_1's auc: 0.795757
# [900]	training's auc: 0.846241	valid_1's auc: 0.796408
# [1000]	training's auc: 0.851726	valid_1's auc: 0.796936
# [1100]	training's auc: 0.857075	valid_1's auc: 0.797243
# [1200]	training's auc: 0.861854	valid_1's auc: 0.797753
# [1300]	training's auc: 0.866643	valid_1's auc: 0.798004
# [1400]	training's auc: 0.87095	valid_1's auc: 0.798098
# [1500]	training's auc: 0.875409	valid_1's auc: 0.798296
# [1600]	training's auc: 0.879568	valid_1's auc: 0.79867
# [1700]	training's auc: 0.88352	valid_1's auc: 0.798618
# Early stopping, best iteration is:
# [1626]	training's auc: 0.880613	valid_1's auc: 0.798832
# Fold  6 AUC : 0.798832
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758303	valid_1's auc: 0.741947
# [200]	training's auc: 0.780495	valid_1's auc: 0.757877
# [300]	training's auc: 0.79782	valid_1's auc: 0.769484
# [400]	training's auc: 0.809615	valid_1's auc: 0.775748
# [500]	training's auc: 0.818868	valid_1's auc: 0.77927
# [600]	training's auc: 0.826935	valid_1's auc: 0.781359
# [700]	training's auc: 0.834158	valid_1's auc: 0.783198
# [800]	training's auc: 0.840512	valid_1's auc: 0.784908
# [900]	training's auc: 0.846556	valid_1's auc: 0.785797
# [1000]	training's auc: 0.852195	valid_1's auc: 0.786222
# [1100]	training's auc: 0.857352	valid_1's auc: 0.787022
# [1200]	training's auc: 0.862176	valid_1's auc: 0.787476
# [1300]	training's auc: 0.866941	valid_1's auc: 0.788306
# [1400]	training's auc: 0.871437	valid_1's auc: 0.788597
# [1500]	training's auc: 0.87565	valid_1's auc: 0.78865
# Early stopping, best iteration is:
# [1441]	training's auc: 0.873258	valid_1's auc: 0.788823
# Fold  7 AUC : 0.788823
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758812	valid_1's auc: 0.745414
# [200]	training's auc: 0.780908	valid_1's auc: 0.760462
# [300]	training's auc: 0.798118	valid_1's auc: 0.770984
# [400]	training's auc: 0.809499	valid_1's auc: 0.776368
# [500]	training's auc: 0.818769	valid_1's auc: 0.779714
# [600]	training's auc: 0.826842	valid_1's auc: 0.781735
# [700]	training's auc: 0.834085	valid_1's auc: 0.782855
# [800]	training's auc: 0.840448	valid_1's auc: 0.784114
# [900]	training's auc: 0.846269	valid_1's auc: 0.784682
# [1000]	training's auc: 0.851918	valid_1's auc: 0.785425
# [1100]	training's auc: 0.857087	valid_1's auc: 0.785558
# [1200]	training's auc: 0.86216	valid_1's auc: 0.786138
# [1300]	training's auc: 0.866771	valid_1's auc: 0.78665
# [1400]	training's auc: 0.871441	valid_1's auc: 0.787028
# Early stopping, best iteration is:
# [1374]	training's auc: 0.870219	valid_1's auc: 0.78708
# Fold  8 AUC : 0.787080
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758426	valid_1's auc: 0.746037
# [200]	training's auc: 0.780494	valid_1's auc: 0.759162
# [300]	training's auc: 0.797813	valid_1's auc: 0.769015
# [400]	training's auc: 0.809511	valid_1's auc: 0.774334
# [500]	training's auc: 0.81887	valid_1's auc: 0.777255
# [600]	training's auc: 0.826905	valid_1's auc: 0.779191
# [700]	training's auc: 0.834004	valid_1's auc: 0.780723
# [800]	training's auc: 0.840466	valid_1's auc: 0.781659
# [900]	training's auc: 0.846204	valid_1's auc: 0.782478
# [1000]	training's auc: 0.851775	valid_1's auc: 0.783006
# [1100]	training's auc: 0.857016	valid_1's auc: 0.783572
# [1200]	training's auc: 0.861649	valid_1's auc: 0.784015
# [1300]	training's auc: 0.866303	valid_1's auc: 0.784383
# [1400]	training's auc: 0.870929	valid_1's auc: 0.785115
# [1500]	training's auc: 0.875345	valid_1's auc: 0.785284
# [1600]	training's auc: 0.879551	valid_1's auc: 0.785754
# [1700]	training's auc: 0.883622	valid_1's auc: 0.785964
# [1800]	training's auc: 0.887649	valid_1's auc: 0.785992
# [1900]	training's auc: 0.891555	valid_1's auc: 0.786461
# [2000]	training's auc: 0.895282	valid_1's auc: 0.786315
# Early stopping, best iteration is:
# [1957]	training's auc: 0.893662	valid_1's auc: 0.786601
# Fold  9 AUC : 0.786601
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757823	valid_1's auc: 0.760044
# [200]	training's auc: 0.780035	valid_1's auc: 0.774334
# [300]	training's auc: 0.79732	valid_1's auc: 0.784852
# [400]	training's auc: 0.808869	valid_1's auc: 0.790544
# [500]	training's auc: 0.818245	valid_1's auc: 0.793962
# [600]	training's auc: 0.826348	valid_1's auc: 0.795631
# [700]	training's auc: 0.833557	valid_1's auc: 0.797171
# [800]	training's auc: 0.840039	valid_1's auc: 0.798324
# [900]	training's auc: 0.84617	valid_1's auc: 0.799047
# [1000]	training's auc: 0.851526	valid_1's auc: 0.799409
# [1100]	training's auc: 0.856593	valid_1's auc: 0.799853
# [1200]	training's auc: 0.861592	valid_1's auc: 0.800244
# [1300]	training's auc: 0.866337	valid_1's auc: 0.800964
# [1400]	training's auc: 0.870765	valid_1's auc: 0.800914
# Early stopping, best iteration is:
# [1353]	training's auc: 0.868624	valid_1's auc: 0.801079
# Fold 10 AUC : 0.801079
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758221	valid_1's auc: 0.751534
# [200]	training's auc: 0.780071	valid_1's auc: 0.770092
# [300]	training's auc: 0.79754	valid_1's auc: 0.78195
# [400]	training's auc: 0.809344	valid_1's auc: 0.787158
# [500]	training's auc: 0.818472	valid_1's auc: 0.790765
# [600]	training's auc: 0.826732	valid_1's auc: 0.79326
# [700]	training's auc: 0.833982	valid_1's auc: 0.79447
# [800]	training's auc: 0.840527	valid_1's auc: 0.795388
# [900]	training's auc: 0.846496	valid_1's auc: 0.796281
# [1000]	training's auc: 0.851952	valid_1's auc: 0.796659
# [1100]	training's auc: 0.857295	valid_1's auc: 0.797039
# [1200]	training's auc: 0.862154	valid_1's auc: 0.796863
# Early stopping, best iteration is:
# [1104]	training's auc: 0.857472	valid_1's auc: 0.797101
# Fold 11 AUC : 0.797101
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757722	valid_1's auc: 0.749411
# [200]	training's auc: 0.779752	valid_1's auc: 0.769804
# [300]	training's auc: 0.796956	valid_1's auc: 0.783801
# [400]	training's auc: 0.808734	valid_1's auc: 0.790475
# [500]	training's auc: 0.818071	valid_1's auc: 0.794051
# [600]	training's auc: 0.826171	valid_1's auc: 0.796403
# [700]	training's auc: 0.833681	valid_1's auc: 0.798199
# [800]	training's auc: 0.8402	valid_1's auc: 0.799387
# [900]	training's auc: 0.846251	valid_1's auc: 0.800498
# [1000]	training's auc: 0.851689	valid_1's auc: 0.801678
# [1100]	training's auc: 0.857054	valid_1's auc: 0.802241
# [1200]	training's auc: 0.861891	valid_1's auc: 0.802699
# [1300]	training's auc: 0.866527	valid_1's auc: 0.802711
# Early stopping, best iteration is:
# [1212]	training's auc: 0.862507	valid_1's auc: 0.802856
# Fold 12 AUC : 0.802856
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758478	valid_1's auc: 0.737736
# [200]	training's auc: 0.780397	valid_1's auc: 0.755286
# [300]	training's auc: 0.797685	valid_1's auc: 0.767111
# [400]	training's auc: 0.80926	valid_1's auc: 0.773091
# [500]	training's auc: 0.818574	valid_1's auc: 0.776622
# [600]	training's auc: 0.826645	valid_1's auc: 0.779081
# [700]	training's auc: 0.833842	valid_1's auc: 0.781279
# [800]	training's auc: 0.840668	valid_1's auc: 0.782675
# [900]	training's auc: 0.846701	valid_1's auc: 0.783612
# [1000]	training's auc: 0.852124	valid_1's auc: 0.784444
# [1100]	training's auc: 0.857333	valid_1's auc: 0.78526
# [1200]	training's auc: 0.862308	valid_1's auc: 0.785898
# [1300]	training's auc: 0.866669	valid_1's auc: 0.786366
# [1400]	training's auc: 0.87127	valid_1's auc: 0.786702
# [1500]	training's auc: 0.875663	valid_1's auc: 0.786865
# Early stopping, best iteration is:
# [1438]	training's auc: 0.873043	valid_1's auc: 0.787053
# Fold 13 AUC : 0.787053
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757974	valid_1's auc: 0.747222
# [200]	training's auc: 0.780229	valid_1's auc: 0.762575
# [300]	training's auc: 0.797702	valid_1's auc: 0.774412
# [400]	training's auc: 0.80947	valid_1's auc: 0.781069
# [500]	training's auc: 0.818653	valid_1's auc: 0.784933
# [600]	training's auc: 0.826628	valid_1's auc: 0.787532
# [700]	training's auc: 0.833875	valid_1's auc: 0.789941
# [800]	training's auc: 0.840422	valid_1's auc: 0.791241
# [900]	training's auc: 0.846511	valid_1's auc: 0.792581
# [1000]	training's auc: 0.85211	valid_1's auc: 0.793619
# [1100]	training's auc: 0.857273	valid_1's auc: 0.794428
# [1200]	training's auc: 0.862167	valid_1's auc: 0.794937
# [1300]	training's auc: 0.866881	valid_1's auc: 0.795466
# [1400]	training's auc: 0.871509	valid_1's auc: 0.795859
# [1500]	training's auc: 0.875831	valid_1's auc: 0.796572
# [1600]	training's auc: 0.87994	valid_1's auc: 0.797081
# [1700]	training's auc: 0.883867	valid_1's auc: 0.797366
# [1800]	training's auc: 0.887829	valid_1's auc: 0.797612
# [1900]	training's auc: 0.891762	valid_1's auc: 0.797988
# [2000]	training's auc: 0.895328	valid_1's auc: 0.798343
# [2100]	training's auc: 0.898867	valid_1's auc: 0.798529
# [2200]	training's auc: 0.902264	valid_1's auc: 0.79854
# Early stopping, best iteration is:
# [2130]	training's auc: 0.899985	valid_1's auc: 0.798632
# Fold 14 AUC : 0.798632
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758473	valid_1's auc: 0.74014
# [200]	training's auc: 0.780425	valid_1's auc: 0.757789
# [300]	training's auc: 0.797731	valid_1's auc: 0.77156
# [400]	training's auc: 0.809379	valid_1's auc: 0.778748
# [500]	training's auc: 0.818569	valid_1's auc: 0.782531
# [600]	training's auc: 0.826668	valid_1's auc: 0.785125
# [700]	training's auc: 0.833938	valid_1's auc: 0.786997
# [800]	training's auc: 0.840487	valid_1's auc: 0.788026
# [900]	training's auc: 0.846281	valid_1's auc: 0.788772
# [1000]	training's auc: 0.851751	valid_1's auc: 0.789528
# [1100]	training's auc: 0.856878	valid_1's auc: 0.790008
# [1200]	training's auc: 0.861556	valid_1's auc: 0.790562
# [1300]	training's auc: 0.866364	valid_1's auc: 0.790769
# [1400]	training's auc: 0.870891	valid_1's auc: 0.790818
# Early stopping, best iteration is:
# [1345]	training's auc: 0.868406	valid_1's auc: 0.79103
# Fold 15 AUC : 0.791030
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757927	valid_1's auc: 0.747158
# [200]	training's auc: 0.780092	valid_1's auc: 0.764743
# [300]	training's auc: 0.797519	valid_1's auc: 0.777252
# [400]	training's auc: 0.809285	valid_1's auc: 0.78354
# [500]	training's auc: 0.818608	valid_1's auc: 0.787179
# [600]	training's auc: 0.826709	valid_1's auc: 0.789591
# [700]	training's auc: 0.833881	valid_1's auc: 0.791091
# [800]	training's auc: 0.840485	valid_1's auc: 0.792412
# [900]	training's auc: 0.846475	valid_1's auc: 0.793373
# [1000]	training's auc: 0.851992	valid_1's auc: 0.793733
# [1100]	training's auc: 0.857164	valid_1's auc: 0.794115
# [1200]	training's auc: 0.862089	valid_1's auc: 0.7942
# [1300]	training's auc: 0.866918	valid_1's auc: 0.79448
# [1400]	training's auc: 0.87152	valid_1's auc: 0.794694
# [1500]	training's auc: 0.875942	valid_1's auc: 0.794794
# Early stopping, best iteration is:
# [1475]	training's auc: 0.874818	valid_1's auc: 0.794928
# Fold 16 AUC : 0.794928
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757923	valid_1's auc: 0.758159
# [200]	training's auc: 0.779888	valid_1's auc: 0.772054
# [300]	training's auc: 0.797301	valid_1's auc: 0.783138
# [400]	training's auc: 0.809088	valid_1's auc: 0.789121
# [500]	training's auc: 0.818504	valid_1's auc: 0.792109
# [600]	training's auc: 0.826482	valid_1's auc: 0.794271
# [700]	training's auc: 0.83388	valid_1's auc: 0.795606
# [800]	training's auc: 0.840305	valid_1's auc: 0.796133
# [900]	training's auc: 0.846502	valid_1's auc: 0.796711
# [1000]	training's auc: 0.852047	valid_1's auc: 0.797041
# [1100]	training's auc: 0.857402	valid_1's auc: 0.797529
# [1200]	training's auc: 0.862408	valid_1's auc: 0.797573
# Early stopping, best iteration is:
# [1174]	training's auc: 0.861007	valid_1's auc: 0.797778
# Fold 17 AUC : 0.797778
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757813	valid_1's auc: 0.758249
# [200]	training's auc: 0.779878	valid_1's auc: 0.775885
# [300]	training's auc: 0.79718	valid_1's auc: 0.788531
# [400]	training's auc: 0.808914	valid_1's auc: 0.794655
# [500]	training's auc: 0.818278	valid_1's auc: 0.798037
# [600]	training's auc: 0.826251	valid_1's auc: 0.800251
# [700]	training's auc: 0.833571	valid_1's auc: 0.801366
# [800]	training's auc: 0.83996	valid_1's auc: 0.802225
# [900]	training's auc: 0.845956	valid_1's auc: 0.80254
# [1000]	training's auc: 0.851409	valid_1's auc: 0.80288
# [1100]	training's auc: 0.856578	valid_1's auc: 0.80329
# [1200]	training's auc: 0.861656	valid_1's auc: 0.802946
# Early stopping, best iteration is:
# [1104]	training's auc: 0.856815	valid_1's auc: 0.803375
# Fold 18 AUC : 0.803375
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758277	valid_1's auc: 0.751239
# [200]	training's auc: 0.780305	valid_1's auc: 0.764836
# [300]	training's auc: 0.797884	valid_1's auc: 0.776957
# [400]	training's auc: 0.809432	valid_1's auc: 0.781803
# [500]	training's auc: 0.818688	valid_1's auc: 0.785183
# [600]	training's auc: 0.827063	valid_1's auc: 0.786848
# [700]	training's auc: 0.83406	valid_1's auc: 0.787733
# [800]	training's auc: 0.840742	valid_1's auc: 0.788181
# [900]	training's auc: 0.846911	valid_1's auc: 0.788797
# [1000]	training's auc: 0.852374	valid_1's auc: 0.788952
# [1100]	training's auc: 0.857692	valid_1's auc: 0.789252
# [1200]	training's auc: 0.862744	valid_1's auc: 0.789366
# [1300]	training's auc: 0.867404	valid_1's auc: 0.78947
# [1400]	training's auc: 0.871674	valid_1's auc: 0.789728
# [1500]	training's auc: 0.876118	valid_1's auc: 0.789807
# Early stopping, best iteration is:
# [1484]	training's auc: 0.875394	valid_1's auc: 0.789995
# Fold 19 AUC : 0.789995
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.757841	valid_1's auc: 0.747684
# [200]	training's auc: 0.780061	valid_1's auc: 0.764871
# [300]	training's auc: 0.797681	valid_1's auc: 0.777957
# [400]	training's auc: 0.809288	valid_1's auc: 0.784635
# [500]	training's auc: 0.81857	valid_1's auc: 0.788412
# [600]	training's auc: 0.826736	valid_1's auc: 0.791149
# [700]	training's auc: 0.833888	valid_1's auc: 0.792893
# [800]	training's auc: 0.840506	valid_1's auc: 0.794022
# [900]	training's auc: 0.84644	valid_1's auc: 0.794664
# [1000]	training's auc: 0.851803	valid_1's auc: 0.795456
# [1100]	training's auc: 0.856986	valid_1's auc: 0.795794
# [1200]	training's auc: 0.862127	valid_1's auc: 0.796384
# [1300]	training's auc: 0.866804	valid_1's auc: 0.797408
# [1400]	training's auc: 0.871381	valid_1's auc: 0.79767
# [1500]	training's auc: 0.875805	valid_1's auc: 0.798298
# [1600]	training's auc: 0.879922	valid_1's auc: 0.79868
# [1700]	training's auc: 0.883912	valid_1's auc: 0.798708
# [1800]	training's auc: 0.887883	valid_1's auc: 0.798625
# Early stopping, best iteration is:
# [1705]	training's auc: 0.884097	valid_1's auc: 0.798739
# Fold 20 AUC : 0.798739
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758364	valid_1's auc: 0.747684
# [200]	training's auc: 0.780383	valid_1's auc: 0.761373
# [300]	training's auc: 0.797629	valid_1's auc: 0.771189
# [400]	training's auc: 0.809439	valid_1's auc: 0.775934
# [500]	training's auc: 0.818866	valid_1's auc: 0.778922
# [600]	training's auc: 0.826947	valid_1's auc: 0.780036
# [700]	training's auc: 0.834219	valid_1's auc: 0.781428
# [800]	training's auc: 0.840647	valid_1's auc: 0.782098
# [900]	training's auc: 0.846461	valid_1's auc: 0.782016
# Early stopping, best iteration is:
# [847]	training's auc: 0.843426	valid_1's auc: 0.782161
# Fold 21 AUC : 0.782161
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758287	valid_1's auc: 0.75472
# [200]	training's auc: 0.780443	valid_1's auc: 0.769351
# [300]	training's auc: 0.797535	valid_1's auc: 0.7799
# [400]	training's auc: 0.809185	valid_1's auc: 0.784785
# [500]	training's auc: 0.818461	valid_1's auc: 0.787846
# [600]	training's auc: 0.826444	valid_1's auc: 0.789287
# [700]	training's auc: 0.833838	valid_1's auc: 0.790654
# [800]	training's auc: 0.840338	valid_1's auc: 0.791648
# [900]	training's auc: 0.846145	valid_1's auc: 0.791963
# [1000]	training's auc: 0.851755	valid_1's auc: 0.792411
# [1100]	training's auc: 0.856898	valid_1's auc: 0.792662
# [1200]	training's auc: 0.861676	valid_1's auc: 0.792858
# [1300]	training's auc: 0.866529	valid_1's auc: 0.793074
# [1400]	training's auc: 0.87103	valid_1's auc: 0.792997
# Early stopping, best iteration is:
# [1319]	training's auc: 0.867305	valid_1's auc: 0.793197
# Fold 22 AUC : 0.793197
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758508	valid_1's auc: 0.758563
# [200]	training's auc: 0.779839	valid_1's auc: 0.774002
# [300]	training's auc: 0.797293	valid_1's auc: 0.783327
# [400]	training's auc: 0.809211	valid_1's auc: 0.787518
# [500]	training's auc: 0.818539	valid_1's auc: 0.789956
# [600]	training's auc: 0.826743	valid_1's auc: 0.791764
# [700]	training's auc: 0.833998	valid_1's auc: 0.792736
# [800]	training's auc: 0.84045	valid_1's auc: 0.793386
# [900]	training's auc: 0.84658	valid_1's auc: 0.793818
# [1000]	training's auc: 0.852077	valid_1's auc: 0.793971
# [1100]	training's auc: 0.8573	valid_1's auc: 0.794298
# [1200]	training's auc: 0.862313	valid_1's auc: 0.794816
# [1300]	training's auc: 0.866803	valid_1's auc: 0.795056
# [1400]	training's auc: 0.871349	valid_1's auc: 0.795087
# Early stopping, best iteration is:
# [1310]	training's auc: 0.86726	valid_1's auc: 0.795193
# Fold 23 AUC : 0.795193
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.758176	valid_1's auc: 0.747568
# [200]	training's auc: 0.78044	valid_1's auc: 0.764054
# [300]	training's auc: 0.79776	valid_1's auc: 0.775347
# [400]	training's auc: 0.809404	valid_1's auc: 0.780833
# [500]	training's auc: 0.818684	valid_1's auc: 0.784034
# [600]	training's auc: 0.826785	valid_1's auc: 0.786269
# [700]	training's auc: 0.833885	valid_1's auc: 0.78692
# [800]	training's auc: 0.840386	valid_1's auc: 0.787781
# [900]	training's auc: 0.846257	valid_1's auc: 0.788652
# [1000]	training's auc: 0.851826	valid_1's auc: 0.78906
# [1100]	training's auc: 0.857364	valid_1's auc: 0.78959
# [1200]	training's auc: 0.862333	valid_1's auc: 0.789685
# [1300]	training's auc: 0.86692	valid_1's auc: 0.78997
# Early stopping, best iteration is:
# [1253]	training's auc: 0.864886	valid_1's auc: 0.790054
# Fold 24 AUC : 0.790054
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.75815	valid_1's auc: 0.747672
# [200]	training's auc: 0.779984	valid_1's auc: 0.765754
# [300]	training's auc: 0.79727	valid_1's auc: 0.778813
# [400]	training's auc: 0.809166	valid_1's auc: 0.785394
# [500]	training's auc: 0.81839	valid_1's auc: 0.788752
# [600]	training's auc: 0.826494	valid_1's auc: 0.791603
# [700]	training's auc: 0.833641	valid_1's auc: 0.793341
# [800]	training's auc: 0.840175	valid_1's auc: 0.794329
# [900]	training's auc: 0.846231	valid_1's auc: 0.794793
# [1000]	training's auc: 0.851646	valid_1's auc: 0.79537
# [1100]	training's auc: 0.857056	valid_1's auc: 0.796018
# [1200]	training's auc: 0.86195	valid_1's auc: 0.796177
# [1300]	training's auc: 0.866572	valid_1's auc: 0.796425
# Early stopping, best iteration is:
# [1279]	training's auc: 0.865525	valid_1's auc: 0.796557
# Fold 25 AUC : 0.796557
# Full AUC score 0.793285

# %%
sub.to_csv('./kageyama_feature_matrix_25cv_tuned_by_Ivan_noIDs_delmissing_sub.csv', index=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

def display_importances(feature_importance_df_):
    # Plot feature importances
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:50].index
    
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    
    plt.figure(figsize=(8,10))
    sns.barplot(x="importance", y="feature", 
                data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()

# %%
display_importances(feature_importance_df)

# %%
time.time() - st
# Out:
# 21087.604503393173

# %%
feature_importances = feature_importance_df[["feature", "importance"]].groupby("feature").mean()

# %%
def norm_feature_importances(df, threshold = 0.95):
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])
    
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df

# %%
norm_feature_importances = norm_feature_importances(feature_importances)
# Out:
# 586 features required for 0.95 of cumulative importance

# %%
# Threshold for cumulative importance
threshold = 0.95

# Extract the features to keep
unimportant_features = list(norm_feature_importances[norm_feature_importances['cumulative_importance'] >= threshold]['feature'])

# %%
df = pd.read_csv('./new_feature_by_kageyama_feature_matrix_noIDs_delmissing.csv')
df = df.drop(unimportant_features, axis=1)
df.to_csv('./new_feature_by_kageyama_feature_matrix_noIDs_delmissing_delunimportant.csv',  index=None)
